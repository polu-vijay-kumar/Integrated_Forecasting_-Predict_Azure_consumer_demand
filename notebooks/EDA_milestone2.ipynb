# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load feature-engineered dataset
df = pd.read_csv("final_feature_engineered_dataset.csv")  # or your processed file

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1080, 34)
#          date  usage_cpu  usage_storage  users_active  economic_index  \
# 0  2023-01-01         88           1959           470          104.97
# 1  2023-01-01         92           1595           388          104.97
# 2  2023-01-01         70            621           414          104.97
# 3  2023-01-01         60           1982           287          104.97
# 4  2023-01-01         85           1371           351          104.97
#
#    cloud_market_demand  holiday  Day_of_Week  Month  month  ...  \
# 0                 0.99        1            6      1      1  ...
# 1                 0.99        1            6      1      1  ...
# 2                 0.99        1            6      1      1  ...
# 3                 0.99        1            6      1      1  ...
# 4                 0.99        1            6      1      1  ...
#
#    utilization_ratio  storage_efficiency  weather_index  power_outage_flag  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

plt.figure(figsize=(14, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(14, 6))
plt.plot(df['date'], df['usage_cpu'], label='CPU Usage')
plt.plot(df['date'], df['usage_storage'], label='Storage Usage')
plt.title('CPU and Storage Usage Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Usage')
plt.legend()
plt.show()

# %%
sns.histplot(df['usage_cpu'], kde=True)
plt.title('CPU Usage Distribution')
plt.show()

# %%
sns.histplot(df['usage_storage'], kde=True)
plt.title('Storage Usage Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='month', y='usage_cpu', data=df)
plt.title('CPU Usage Seasonality by Month')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='day_of_week', y='usage_cpu', data=df)
plt.title('CPU Usage by Day of Week')
plt.show()

# %%
processed_path = "data/processed/feature_engineered.csv"
import os
os.makedirs("data/processed", exist_ok=True)
df.to_csv(processed_path, index=False)
print(f"✅ Final dataset saved at {processed_path}")
# Out:
# ✅ Final dataset saved at data/processed/feature_engineered.csv
